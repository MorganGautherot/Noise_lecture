# %% [markdown]
# # Prétraitement des données audio

# %% [markdown]
# # Importation des packages

# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
import json
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %% [markdown]
# # Connection avec Google Drive

# %% [markdown]
# Ajoutez un raccourci de ce dossier à votre Google Drive :
#
# https://drive.google.com/drive/folders/1NGH6ntk3qH8Odo7q8YxDS0iqV-httZUR?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # RNN

# %% [markdown]
# Création du générateur

# %% [markdown]
# Séparez les données explicatives de la variable cible.

# %%
def load_data(dataset_path:str):
  with open(dataset_path, "r") as fp:
    data = json.load(fp)

    # Convert lists into numpy arrays
    inputs = None
    targets = None

    return inputs, targets

# %% [markdown]
# Utilisez la fonction précédemment créé.

# %%
x, y = None

# %% [markdown]
# Utilisez la fonction `train_test_split` pour séparer le jeu de données d'entraînement et de test.

# %%
x_train, x_test, y_train, y_test = None

# %% [markdown]
# Extraire les dimensons intéréssantes de `x_train`.

# %%
input_shape = None

# %% [markdown]
# Intiialisation du modèle

# %% [markdown]
# Utilisez `Sequential` pour initialiser l'architecture suivante:
# - Une couche de `LSTM` qui retourne une séquence avec 64 neurones.
# - Une couche de `LSTM` qui retourne un vecteur.
# - Une couche `Dense` avec 64 neurones et avec relu pour fonction d'activation.
# - Une couche `Dense` de 10 neurones avec softmax pour fonction d'acitvation.

# %%
def build_model(inpust_shape):
  # create model
  model = None

  return model

# %% [markdown]
# Utilisez la fonction précédente.

# %%
  # Build the CNN net
  model = None

# %% [markdown]
# Choix de l'optimisateur

# %% [markdown]
# Utilisez la fonction `Adam` avec 0.0001 comme laerning rate.a

# %%
optimizer = None

# %% [markdown]
# Compilation du modèle

# %% [markdown]
# Utilisez la `sparse_categorical_crossentropy` comme fonction de coût et l'accuracy comme métrique.

# %%
None

# %% [markdown]
# Visualisez le modèle grâce à la méthode `summary`.

# %%
None

# %% [markdown]
# Entraîner le modèle en utilisant les données d'entraînement, les données de test pour la `validation_data`, un batch size de 32 et 50 epochs.

# %%
history = None

# %% [markdown]
# Visualisation des performances lors de l'entraînement

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
# plot accuracy/error for training and validation
plot_history(history)

# evaluate model on test set
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
